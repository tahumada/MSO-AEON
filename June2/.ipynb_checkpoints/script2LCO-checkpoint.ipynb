# %%
# add filter
import copy
import glob
import numpy as np
from datetime import datetime, timedelta
import os
import re
import requests
import json
from astropy.time import Time
import pandas as pd
from astropy.coordinates import SkyCoord
import astropy.units as u

def standardize_to_degrees(ra, dec):
    ra_str = str(ra).strip()
    
    if any(char in ra_str for char in [':', 'h', ' ']):
        # It is sexagesimal. We assume RA is in hours and Dec is in degrees.
        coord = SkyCoord(ra=ra, dec=dec, unit=(u.hourangle, u.deg))
        return coord.ra.deg, coord.dec.deg
    else:
        return float(ra), float(dec)

# %%
# get your LCO token from https://observe.lco.global/accounts/profile

from dotenv import load_dotenv

load_dotenv()

LCO_TOKEN = os.getenv('LCO_TOKEN')

if LCO_TOKEN:
    print("Successfully loaded the LCO token!")
else:
    print("Token not found. Check your .env file.")
    
requestpath  = "https://observe.lco.global/api/requestgroups/"
# Out:
# Successfully loaded the LCO token!

# %%
# path to your usual DECam script
date = 'June2'
decam_script_path = f'../{date}/scriptsytabledeoffsets/Starflat_Field3_g.json'
decam_script = pd.read_json(decam_script_path)

# %%
decam_script
# Out:
#    expType       object filter           RA          dec      propid proposer  \
# 0   object  star flat g      g  13:27:00.00  -48:45:00.0  2013A-9999   Walker
# 1   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 2   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 3   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 4   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 5   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 6   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 7   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 8   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 9   object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 10  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 11  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 12  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 13  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 14  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 15  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 16  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 17  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 18  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 19  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 20  object  star flat g      g          NaN          NaN  2013A-9999   Walker
# 21  object  star flat g      g          NaN          NaN  2013A-9999   Walker
#
#     expTime  deltaDEC  deltaRA
# 0        30       NaN      NaN
# 1        30      65.0    100.0
# 2        30      -8.0   -199.0
# 3        30    -287.0    -94.0
# 4        30      94.0    460.0
# 5        30    -294.0    150.0
# 6        30     983.0   -184.0
# 7        30      75.0    707.0
# 8        30      -7.0  -1886.0
# 9        30   -1478.0   2371.0
# 10       30     867.0  -1420.0
# 11       30    1637.0    226.0
# 12       30    -342.0  -1995.0
# 13       30   -3439.0   1253.0
# 14       30    4834.0    881.0
# 15       30   -3414.0  -3000.0
# 16       30    3053.0    363.0
# 17       30   -5340.0   1000.0
# 18       30    2849.0  -2518.0
# 19       30   -3273.0   5404.0
# 20       30    5287.0   1419.0
# 21       30   -1857.0  -3028.0

# %%
example_path = '../example.json'

with open(example_path, "r") as f:
        data = json.load(f)

i = 0

# load name, ra, dec, propid
name = decam_script['object'].iloc[i]
ra = decam_script['RA'].iloc[i]
dec = decam_script['dec'].iloc[i]
ra, dec = standardize_to_degrees(ra, dec)
# propid = decam_script['propid'].iloc[i]
propid = '2025B-589422'

# modify priority
data['proposal'] = propid
data['ipp_value'] = 0.9

# modify target
target = data['requests'][0]['configurations'][0]['target']
target['name'] = name
data['name'] = name

target['ra'] = ra
target['dec'] = dec

for i in range(len(decam_script)):
    # configurations : filters and offsets
    # load filters and offsets
    
    filt = decam_script['filter'].iloc[i]
    exp_time = decam_script['expTime'].iloc[i]
    deltaRA = decam_script['deltaRA'].iloc[i]
    deltaRA = 0.0 if pd.isna(deltaRA) else float(deltaRA)
    deltaDEC = decam_script['deltaDEC'].iloc[i]
    deltaDEC = 0.0 if pd.isna(deltaDEC) else float(deltaDEC)
    
    instrument_configs = data['requests'][0]['configurations'][0]['instrument_configs']
    instrument_configs[0]['exposure_time'] = int(exp_time)
    instrument_configs[0]['optical_elements']['filter'] = filt
    instrument_configs[0]['extra_params']['offset_ra'] = deltaRA
    instrument_configs[0]['extra_params']['offset_dec'] = deltaDEC


    if i == 0:
        original_config = instrument_configs[0]
    
    
    if i > 0:
        added_config = copy.deepcopy(original_config)
        added_config['exposure_time'] = int(exp_time)
        added_config['optical_elements']['filter'] = filt
        added_config['extra_params']['offset_ra'] = deltaRA
        added_config['extra_params']['offset_dec'] = deltaDEC
        instrument_configs.append(added_config)
    

# time window
window_date = Time('2026-06-02 00:00:00',format='iso')
window_original = data['requests'][0]['windows'][0]
window_original['start'] = (window_date - timedelta(minutes=30)).strftime("%Y-%m-%d %H:%M:%S")
window_original['end'] = (window_date + timedelta(days=1)).strftime("%Y-%m-%d %H:%M:%S")

# %%
# posting

response = requests.post(
            requestpath,
            headers={"Authorization": f"Token {LCO_TOKEN}"},
            json=data,  # Make sure you use json!
        )


sent,failed = [],[]

if response.status_code == 400:
    print('Failed to send request, it is not in the queue')
    failed.append([data['name'],response.text])
if response.status_code == 200 or response.status_code == 201:
    print(f'Success!! request should be in the queue. https://observe.lco.global/requests/{response.json()['requests'][0]['id']}')
    print('name:', data['name'], 'RequestGroup:',response.json()['id'])
    sent.append(response.json()['id'])
    
# data
np.save(f'../{date}/sent.npy',sent)
np.save(f'../{date}/failed.npy',failed)
# Out:
# star flat g 2526150

# %%
response.text
# Out:
# '{"id":2526150,"requests":[{"id":4205995,"location":{"telescope_class":"4m0"},"configurations":[{"id":15012431,"constraints":{"max_airmass":1.6,"min_lunar_distance":30.0,"max_lunar_phase":1.0,"max_seeing":null,"min_transparency":null,"extra_params":{}},"instrument_configs":[{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-3028,"offset_dec":-1857}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":100,"offset_dec":65}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-199,"offset_dec":-8}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-94,"offset_dec":-287}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":460,"offset_dec":94}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":150,"offset_dec":-294}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-184,"offset_dec":983}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":707,"offset_dec":75}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-1886,"offset_dec":-7}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":2371,"offset_dec":-1478}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-1420,"offset_dec":867}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":226,"offset_dec":1637}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-1995,"offset_dec":-342}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":1253,"offset_dec":-3439}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":881,"offset_dec":4834}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-3000,"offset_dec":-3414}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":363,"offset_dec":3053}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":1000,"offset_dec":-5340}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-2518,"offset_dec":2849}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":5404,"offset_dec":-3273}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":1419,"offset_dec":5287}},{"exposure_time":30.0,"optical_elements":{"filter":"g"},"mode":"default","exposure_count":1,"rotator_mode":"","extra_params":{"offset_ra":-3028,"offset_dec":-1857}}],"acquisition_config":{"mode":"OFF","exposure_time":null,"extra_params":{}},"guiding_config":{"optional":true,"mode":"ON","optical_elements":{}," ...

# %%
data
# Out:
# {'id': 2495241,
#  'requests': [{'id': 4168585,
#    'location': {'telescope_class': '4m0'},
#    'configurations': [{'id': 14811742,
#      'constraints': {'max_airmass': 1.6,
#       'min_lunar_distance': 30.0,
#       'max_lunar_phase': 1.0,
#       'max_seeing': None,
#       'min_transparency': None,
#       'extra_params': {}},
#      'instrument_configs': [{'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -3028.0, 'offset_dec': -1857.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 100.0, 'offset_dec': 65.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -199.0, 'offset_dec': -8.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -94.0, 'offset_dec': -287.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 460.0, 'offset_dec': 94.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 150.0, 'offset_dec': -294.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -184.0, 'offset_dec': 983.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 707.0, 'offset_dec': 75.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -1886.0, 'offset_dec': -7.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 2371.0, 'offset_dec': -1478.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -1420.0, 'offset_dec': 867.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 226.0, 'offset_dec': 1637.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -1995.0, 'offset_dec': -342.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 1253.0, 'offset_dec': -3439.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 881.0, 'offset_dec': 4834.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -3000.0, 'offset_dec': -3414.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 363.0, 'offset_dec': 3053.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 1000.0, 'offset_dec': -5340.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -2518.0, 'offset_dec': 2849.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 5404.0, 'offset_dec': -3273.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': 1419.0, 'offset_dec': 5287.0}},
#       {'exposure_time': 30,
#        'optical_elements': {'filter': 'g'},
#        'mode': 'default',
#        'exposure_count': 1,
#        'rotator_mode': '',
#        'extra_params': {'offset_ra': -3028.0, 'offset_dec': -1857.0}}],
#      'acquisition_config': {'mode': 'OFF',
#       'exposure_time': None,
#       'extra_params': {}},
#      'guiding_config': {'optional': True,
#       'mode': 'ON',
#       'optical_elements': {},
#       'exposure_time': None,
#       'extra_params': {}},
#      'target': {'type': 'ICRS',
#       'name': 'star flat g',
#       'ra': np.float64(201.74999999999997),
#       'dec': np.float64(-48.75),
#       'proper_motion_ra': 0.0,
#       'proper_motion_dec': 0.0,
#       'parallax': 0.0,
#       'epoch': 2000.0,
#       'extra_params': {}},
#      'instrument_type': 'BLANCO_DECAM',
#      'type': 'EXPOSE',
#      'extra_params': {'detector_centering': 'S4'},
#      'priority': 1}],
#    'windows': [{'start': '2026-06-01 23:30:00', 'end': '2026-06-03 00:00:00'}],
#    'duration': 713,
#    'observation_note': '',
#    'optimization_type': 'TIME',
#    'state': 'PENDING',
#    'suspend_until': None,
#    'modified': '2026-04-21T20:27:19.068207Z',
#    'created': '2026-04-21T20:27:19.068214Z',
#    'acceptability_threshold': 90.0,
#    'configuration_repeats': 1,
#    'extra_params': {}}],
#  'submitter': 'tahumada',
#  'name': 'star flat g',
#  'observation_type': 'NORMAL',
#  'operator': 'SINGLE',
#  'ipp_value': 0.9,
#  'created': '2026-04-21T20:27:19.066054Z',
#  'state': 'PENDING',
#  'modified': '2026-04-21T20:27:19.066067Z',
#  'proposal': '2025B-589422'}
